# %%
import numpy as np
import pandas as pd
# %matplotlib inline

# %%
df=pd.read_csv('C:/Users/anuj/Documents/Anuj/MMA/Udemy/Python/Time Series/UDEMY_TSA_FINAL/Data/airline_passengers.csv',index_col='Month',parse_dates=True)

# %%
df.index.freq='MS'

# %%
df.head()
# Out:
#             Thousands of Passengers
# Month
# 1949-01-01                      112
# 1949-02-01                      118
# 1949-03-01                      132
# 1949-04-01                      129
# 1949-05-01                      121

# %%
from statsmodels.graphics.tsaplots import month_plot,quarter_plot

# %%
month_plot(df['Thousands of Passengers']);

# %%
df_quarter=df['Thousands of Passengers'].resample(rule='Q').mean()

# %%
quarter_plot(df_quarter);
