# %%
import numpy as np
import pandas as pd
# %matplotlib inline
from matplotlib import dates

# %%
date=np.array(['2020-01-01','2020-01-02','2020-01-31'],dtype='datetime64[D]')

# %%
np.arange('2021-01-01','2021-02-09',1,dtype='datetime64[D]')
# Out:
# array(['2021-01-01', '2021-01-02', '2021-01-03', '2021-01-04',
#        '2021-01-05', '2021-01-06', '2021-01-07', '2021-01-08',
#        '2021-01-09', '2021-01-10', '2021-01-11', '2021-01-12',
#        '2021-01-13', '2021-01-14', '2021-01-15', '2021-01-16',
#        '2021-01-17', '2021-01-18', '2021-01-19', '2021-01-20',
#        '2021-01-21', '2021-01-22', '2021-01-23', '2021-01-24',
#        '2021-01-25', '2021-01-26', '2021-01-27', '2021-01-28',
#        '2021-01-29', '2021-01-30', '2021-01-31', '2021-02-01',
#        '2021-02-02', '2021-02-03', '2021-02-04', '2021-02-05',
#        '2021-02-06', '2021-02-07', '2021-02-08'], dtype='datetime64[D]')

# %%
x=pd.date_range(start='2020-08-01',periods=30,freq='D')

# %%
pd.to_datetime(['01/08/2020','02/08/2020'],format='%d/%m/%Y')
# Out:
# DatetimeIndex(['2020-08-01', '2020-08-02'], dtype='datetime64[ns]', freq=None)

# %%
df=pd.read_csv('C:/Users/anuj/Documents/Anuj/MMA/Udemy/Python/Time Series/UDEMY_TSA_FINAL/Data/starbucks.csv',index_col='Date',parse_dates=True)

# %%
df.index
# Out:
# DatetimeIndex(['2015-01-02', '2015-01-05', '2015-01-06', '2015-01-07',
#                '2015-01-08', '2015-01-09', '2015-01-12', '2015-01-13',
#                '2015-01-14', '2015-01-15',
#                ...
#                '2018-12-17', '2018-12-18', '2018-12-19', '2018-12-20',
#                '2018-12-21', '2018-12-24', '2018-12-26', '2018-12-27',
#                '2018-12-28', '2018-12-31'],
#               dtype='datetime64[ns]', name='Date', length=1006, freq=None)

# %%
df.resample(rule='A').mean()
# Out:
#                 Close        Volume
# Date
# 2015-12-31  50.078100  8.649190e+06
# 2016-12-31  53.891732  9.300633e+06
# 2017-12-31  55.457310  9.296078e+06
# 2018-12-31  56.870005  1.122883e+07

# %%
df.shift(periods=1)
# Out:
#               Close      Volume
# Date
# 2015-01-02      NaN         NaN
# 2015-01-05  38.0061   6906098.0
# 2015-01-06  37.2781  11623796.0
# 2015-01-07  36.9748   7664340.0
# 2015-01-08  37.8848   9732554.0
# ...             ...         ...
# 2018-12-24  61.3900  23524888.0
# 2018-12-26  60.5600   6323252.0
# 2018-12-27  63.0800  16646238.0
# 2018-12-28  63.2000  11308081.0
# 2018-12-31  63.3900   7712127.0
#
# [1006 rows x 2 columns]

# %%
df.head()
# Out:
#               Close    Volume
# Date
# 2015-01-02  38.0061   6906098
# 2015-01-05  37.2781  11623796
# 2015-01-06  36.9748   7664340
# 2015-01-07  37.8848   9732554
# 2015-01-08  38.4961  13170548

# %%
df['Close'].plot()
df.rolling(window=90).mean()['Close'].plot()

# %%
df['Closing:30 Day Mean']=df['Close'].rolling(window=30).mean()

# %%
df['Close'].plot()
df['Close'].rolling(30).mean().plot()

# %%
df['Close'].plot(legend='Closing Price')
df['Closing:30 Day Mean'].plot(legend='Mean Closing')
df['Close'].expanding().mean().plot(legend='Expanding Closing')

# %%
df.plot()
df['Close'].plot()

# %%
df['Close'].plot();

# %%
df['Close']['2017-01-01':'2017-03-31'].plot(title='Closing Price in First Quarter of 2017',ylabel='Closing Price');

# %%
plt=df['Close']['2017-01-01':'2017-03-31'].plot(title='Closing Price in First Quarter of 2017',ylabel='Closing Price',figsize=(12,6));

plt.xaxis.set_major_locator(dates.WeekdayLocator(byweekday=0))
plt.xaxis.set_major_formatter(dates.DateFormatter('%d'))

plt.xaxis.set_minor_locator(dates.MonthLocator())
plt.xaxis.set_minor_formatter(dates.DateFormatter('\n\n%b'))

plt.xaxis.grid(True)
plt.yaxis.grid(True)

# %%
df1=pd.read_csv('C:/Users/anuj/Documents/Anuj/MMA/Udemy/Python/Time Series/UDEMY_TSA_FINAL/Data/monthly_milk_production.csv',index_col='Date',parse_dates=True)

# %%
df1.head()
# Out:
#             Production
# Date
# 1962-01-01         589
# 1962-02-01         561
# 1962-03-01         640
# 1962-04-01         656
# 1962-05-01         727

# %% [markdown]
# # TIME SERIES FORECASTING
